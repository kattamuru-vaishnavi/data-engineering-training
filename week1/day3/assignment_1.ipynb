-- %%
%sql
CREATE OR REPLACE TABLE Employee (
emp_id INT,
emp_name VARCHAR(50),
department VARCHAR(50),
salary INT,
experience INT,
performance_rating CHAR(1));
INSERT INTO Employee (emp_id, emp_name, department, salary, experience, performance_rating) VALUES
(1, 'Karthik', 'Engineering', 95000, 9, 'A'),
(2, 'Prathik', 'HR', 55000, 4, 'B'),
(3, 'Vinay', 'Finance', 78000, 10, 'B'),
(4, 'Vijay', 'Marketing', 48000, 3, 'C'),
(5, 'Anil', 'Engineering', 88000, 6, 'A'),
(6, 'Suresh', 'Finance', 92000, 12, 'A'),
(7, 'Ramesh', 'HR', 46000, 2, 'C'),
(8, 'Mahesh', 'Marketing', 67000, 7, 'B'),
(9, 'Rajesh', 'Engineering', 72000, 5, 'B'),
(10,'Naveen', 'Finance', 61000, 6, 'C'),
(11,'Deepak', 'HR', 83000, 11, 'A'),
(12,'Arjun', 'Engineering', 54000, 3, 'C'),
(13,'Kiran', 'Marketing', 76000, 8, 'A'),
(14,'Rohit', 'Finance', 68000, 4, 'B'),
(15,'Pavan', 'HR', 59000, 5, 'B'),
(16,'Srikanth', 'Engineering', 102000, 14, 'A'),
(17,'Manoj', 'Finance', 47000, 2, 'C'),
(18,'Varun', 'Marketing', 52000, 6, 'B'),
(19,'Ashok', 'HR', 74000, 9, 'A'),
(20,'Sunil', 'Engineering', 66000, 4, 'B'),
(21,'Nikhil', 'Finance', 86000, 7, 'A'),
(22,'Harish', 'Marketing', 45000, 1, 'C'),
(23,'Vamsi', 'Engineering', 79000, 8, 'B'),
(24,'Chaitanya','HR', 91000, 13, 'A'),
(25,'Lokesh', 'Finance', 58000, 5, 'B');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>25</td><td>25</td></tr></tbody></table></div>

-- %%
--Problem 1: Salary Hike Based on Experience and Performance Scenario: You want to give a salary hike based on both experience and performance rating. If the employee has: · Experience ≥ 8 and Performance 'A', they get a 20% hike. · Experience ≥ 5 and Performance 'B', they get a 15% hike. · Performance 'C' gets no hike. · For other cases, they get a 10% hike.


SELECT emp_id,emp_name,experience,salary,
CASE
    WHEN experience >=8 AND performance_rating = 'A' THEN salary*0.20
    WHEN experience >=5 AND performance_rating = 'B' THEN salary*0.15
    WHEN performance_rating = 'C' THEN salary*1
    ELSE salary*1.10
END AS Bonous
FROM Employee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>experience</th><th>salary</th><th>Bonous</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>9</td><td>95000</td><td>19000.00</td></tr><tr><td>2</td><td>Prathik</td><td>4</td><td>55000</td><td>60500.00</td></tr><tr><td>3</td><td>Vinay</td><td>10</td><td>78000</td><td>11700.00</td></tr><tr><td>4</td><td>Vijay</td><td>3</td><td>48000</td><td>48000.00</td></tr><tr><td>5</td><td>Anil</td><td>6</td><td>88000</td><td>96800.00</td></tr><tr><td>6</td><td>Suresh</td><td>12</td><td>92000</td><td>18400.00</td></tr><tr><td>7</td><td>Ramesh</td><td>2</td><td>46000</td><td>46000.00</td></tr><tr><td>8</td><td>Mahesh</td><td>7</td><td>67000</td><td>10050.00</td></tr><tr><td>9</td><td>Rajesh</td><td>5</td><td>72000</td><td>10800.00</td></tr><tr><td>10</td><td>Naveen</td><td>6</td><td>61000</td><td>61000.00</td></tr><tr><td>11</td><td>Deepak</td><td>11</td><td>83000</td><td>16600.00</td></tr><tr><td>12</td><td>Arjun</td><td>3</td><td>54000</td><td>54000.00</td></tr><tr><td>13</td><td>Kiran</td><td>8</td><td>76000</td><td>15200.00</td></tr><tr><td>14</td><td>Rohit</td><td>4</td><td>68000</td><td>74800.00</td></tr><tr><td>15</td><td>Pavan</td><td>5</td><td>59000</td><td>8850.00</td></tr><tr><td>16</td><td>Srikanth</td><td>14</td><td>102000</td><td>20400.00</td></tr><tr><td>17</td><td>Manoj</td><td>2</td><td>47000</td><td>47000.00</td></tr><tr><td>18</td><td>Varun</td><td>6</td><td>52000</td><td>7800.00</td></tr><tr><td>19</td><td>Ashok</td><td>9</td><td>74000</td><td>14800.00</td></tr><tr><td>20</td><td>Sunil</td><td>4</td><td>66000</td><td>72600.00</td></tr><tr><td>21</td><td>Nikhil</td><td>7</td><td>86000</td><td>94600.00</td></tr><tr><td>22</td><td>Harish</td><td>1</td><td>45000</td><td>45000.00</td></tr><tr><td>23</td><td>Vamsi</td><td>8</td><td>79000</td><td>11850.00</td></tr><tr><td>24</td><td>Chaitanya</td><td>13</td><td>91000</td><td>18200.00</td></tr><tr><td>25</td><td>Lokesh</td><td>5</td><td>58000</td><td>8700.00</td></tr></tbody></table></div>

-- %%
--Problem 2: Bonus Calculation Based on Department and Performance Scenario: Bonus is calculated based on the department and performance rating: · For Finance department: o If performance is 'A', the bonus is 20% of the salary. o If performance is 'B', the bonus is 15% of the salary. o If performance is 'C', the bonus is 5% of the salary. · For Engineering department: o If performance is 'A', the bonus is 18% of the salary. o If performance is 'B', the bonus is 12% of the salary. o If performance is 'C', the bonus is 3% of the salary. · For other departments, a flat 10% bonus.


SELECT emp_name, department, salary,
CASE 
    WHEN department = 'Finance' AND performance_rating = 'A' THEN salary * 0.20
    WHEN department = 'Finance' AND performance_rating = 'B' THEN salary * 0.15
    WHEN department = 'Finance' AND performance_rating = 'C' THEN salary * 0.05

    WHEN department = 'Engineering' AND performance_rating = 'A' THEN salary * 0.18
    WHEN department = 'Engineering' AND performance_rating = 'B' THEN salary * 0.12
    WHEN department = 'Engineering' AND performance_rating = 'C' THEN salary * 0.03

    ELSE salary * 0.10
END AS bonus
FROM Employee;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>department</th><th>salary</th><th>bonus</th></tr></thead><tbody><tr><td>Karthik</td><td>Engineering</td><td>95000</td><td>17100.00</td></tr><tr><td>Prathik</td><td>HR</td><td>55000</td><td>5500.00</td></tr><tr><td>Vinay</td><td>Finance</td><td>78000</td><td>11700.00</td></tr><tr><td>Vijay</td><td>Marketing</td><td>48000</td><td>4800.00</td></tr><tr><td>Anil</td><td>Engineering</td><td>88000</td><td>15840.00</td></tr><tr><td>Suresh</td><td>Finance</td><td>92000</td><td>18400.00</td></tr><tr><td>Ramesh</td><td>HR</td><td>46000</td><td>4600.00</td></tr><tr><td>Mahesh</td><td>Marketing</td><td>67000</td><td>6700.00</td></tr><tr><td>Rajesh</td><td>Engineering</td><td>72000</td><td>8640.00</td></tr><tr><td>Naveen</td><td>Finance</td><td>61000</td><td>3050.00</td></tr><tr><td>Deepak</td><td>HR</td><td>83000</td><td>8300.00</td></tr><tr><td>Arjun</td><td>Engineering</td><td>54000</td><td>1620.00</td></tr><tr><td>Kiran</td><td>Marketing</td><td>76000</td><td>7600.00</td></tr><tr><td>Rohit</td><td>Finance</td><td>68000</td><td>10200.00</td></tr><tr><td>Pavan</td><td>HR</td><td>59000</td><td>5900.00</td></tr><tr><td>Srikanth</td><td>Engineering</td><td>102000</td><td>18360.00</td></tr><tr><td>Manoj</td><td>Finance</td><td>47000</td><td>2350.00</td></tr><tr><td>Varun</td><td>Marketing</td><td>52000</td><td>5200.00</td></tr><tr><td>Ashok</td><td>HR</td><td>74000</td><td>7400.00</td></tr><tr><td>Sunil</td><td>Engineering</td><td>66000</td><td>7920.00</td></tr><tr><td>Nikhil</td><td>Finance</td><td>86000</td><td>17200.00</td></tr><tr><td>Harish</td><td>Marketing</td><td>45000</td><td>4500.00</td></tr><tr><td>Vamsi</td><td>Engineering</td><td>79000</td><td>9480.00</td></tr><tr><td>Chaitanya</td><td>HR</td><td>91000</td><td>9100.00</td></tr><tr><td>Lokesh</td><td>Finance</td><td>58000</td><td>8700.00</td></tr></tbody></table></div>

-- %%
--Problem 3: Categorizing Employees by Salary Range and Performance Scenario: You want to categorize employees based on salary ranges and their performance: · If salary is greater than 80,000 and performance is 'A', label them as High Performer. · If salary is between 50,000 and 80,000 and performance is 'B', label them as Mid Performer. · If salary is less than 50,000 or performance is 'C', label them as Low Performer.


SELECT emp_name, salary, performance_rating,
CASE 
    WHEN salary > 80000 AND performance_rating = 'A' THEN 'High Performer'
    WHEN salary BETWEEN 50000 AND 80000 OR performance_rating = 'B' THEN 'Mid Performer'
    WHEN salary < 50000 OR performance_rating = 'C' THEN 'Low Performer'
END AS category
FROM Employee;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>performance_rating</th><th>category</th></tr></thead><tbody><tr><td>Karthik</td><td>95000</td><td>A</td><td>High Performer</td></tr><tr><td>Prathik</td><td>55000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Vinay</td><td>78000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Vijay</td><td>48000</td><td>C</td><td>Low Performer</td></tr><tr><td>Anil</td><td>88000</td><td>A</td><td>High Performer</td></tr><tr><td>Suresh</td><td>92000</td><td>A</td><td>High Performer</td></tr><tr><td>Ramesh</td><td>46000</td><td>C</td><td>Low Performer</td></tr><tr><td>Mahesh</td><td>67000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Rajesh</td><td>72000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Naveen</td><td>61000</td><td>C</td><td>Mid Performer</td></tr><tr><td>Deepak</td><td>83000</td><td>A</td><td>High Performer</td></tr><tr><td>Arjun</td><td>54000</td><td>C</td><td>Mid Performer</td></tr><tr><td>Kiran</td><td>76000</td><td>A</td><td>Mid Performer</td></tr><tr><td>Rohit</td><td>68000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Pavan</td><td>59000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Srikanth</td><td>102000</td><td>A</td><td>High Performer</td></tr><tr><td>Manoj</td><td>47000</td><td>C</td><td>Low Performer</td></tr><tr><td>Varun</td><td>52000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Ashok</td><td>74000</td><td>A</td><td>Mid Performer</td></tr><tr><td>Sunil</td><td>66000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Nikhil</td><td>86000</td><td>A</td><td>High Performer</td></tr><tr><td>Harish</td><td>45000</td><td>C</td><td>Low Performer</td></tr><tr><td>Vamsi</td><td>79000</td><td>B</td><td>Mid Performer</td></tr><tr><td>Chaitanya</td><td>91000</td><td>A</td><td>High Performer</td></tr><tr><td>Lokesh</td><td>58000</td><td>B</td><td>Mid Performer</td></tr></tbody></table></div>

-- %%
--Problem 4: Risk Assessment Based on Experience and Department Scenario: You want to assess employee risk based on their experience and department: · For employees in the HR department: o If experience is less than 5 years, they are High Risk. o If experience is more than 5 years, they are Low Risk. · For employees in Engineering or Finance departments: o If experience is more than 8 years, they are Low Risk. o If experience is less than 8 years, they are Medium Risk. · Employees in other departments are automatically labeled Medium Risk.


SELECT emp_name,department,
CASE
    WHEN department='HR' AND experience<5 THEN 'High Risk'
    WHEN department='HR' AND experience>5 THEN 'Low Risk'
    WHEN department IN ('Finance','Engineering') AND experience>8 THEN 'Low Risk'
    WHEN department IN ('Finance','Engineering') AND experience<8 THEN 'High Risk'
    ELSE 'Medium Risk'
END AS Risk
FROM Employee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>department</th><th>Risk</th></tr></thead><tbody><tr><td>Karthik</td><td>Engineering</td><td>Low Risk</td></tr><tr><td>Prathik</td><td>HR</td><td>High Risk</td></tr><tr><td>Vinay</td><td>Finance</td><td>Low Risk</td></tr><tr><td>Vijay</td><td>Marketing</td><td>Medium Risk</td></tr><tr><td>Anil</td><td>Engineering</td><td>High Risk</td></tr><tr><td>Suresh</td><td>Finance</td><td>Low Risk</td></tr><tr><td>Ramesh</td><td>HR</td><td>High Risk</td></tr><tr><td>Mahesh</td><td>Marketing</td><td>Medium Risk</td></tr><tr><td>Rajesh</td><td>Engineering</td><td>High Risk</td></tr><tr><td>Naveen</td><td>Finance</td><td>High Risk</td></tr><tr><td>Deepak</td><td>HR</td><td>Low Risk</td></tr><tr><td>Arjun</td><td>Engineering</td><td>High Risk</td></tr><tr><td>Kiran</td><td>Marketing</td><td>Medium Risk</td></tr><tr><td>Rohit</td><td>Finance</td><td>High Risk</td></tr><tr><td>Pavan</td><td>HR</td><td>Medium Risk</td></tr><tr><td>Srikanth</td><td>Engineering</td><td>Low Risk</td></tr><tr><td>Manoj</td><td>Finance</td><td>High Risk</td></tr><tr><td>Varun</td><td>Marketing</td><td>Medium Risk</td></tr><tr><td>Ashok</td><td>HR</td><td>Low Risk</td></tr><tr><td>Sunil</td><td>Engineering</td><td>High Risk</td></tr><tr><td>Nikhil</td><td>Finance</td><td>High Risk</td></tr><tr><td>Harish</td><td>Marketing</td><td>Medium Risk</td></tr><tr><td>Vamsi</td><td>Engineering</td><td>Medium Risk</td></tr><tr><td>Chaitanya</td><td>HR</td><td>Low Risk</td></tr><tr><td>Lokesh</td><td>Finance</td><td>High Risk</td></tr></tbody></table></div>

-- %%
--Nested case and when
--Problem 1: Nested CASE for Performance and Salary Hike Based on Multiple Criteria Scenario: You want to determine the salary hike based on performance rating, experience, and current salary. The hike rules are: · If performance is 'A': o For salaries above 80,000, experience above 5 years gets a 25% hike, otherwise 20%. o For salaries between 50,000 and 80,000, the hike is 15%. · If performance is 'B': o For experience above 5 years, the hike is 12%. o Otherwise, it's 10%. · For performance 'C', there is no hike.


SELECT emp_name, salary,
CASE 
    WHEN performance_rating = 'A' THEN 
        CASE 
            WHEN salary > 80000 AND experience > 5 THEN salary * 1.25
            WHEN salary > 80000 THEN salary * 1.20
            WHEN salary BETWEEN 50000 AND 80000 THEN salary * 1.15
        END

    WHEN performance_rating = 'B' THEN 
        CASE 
            WHEN experience > 5 THEN salary * 1.12
            ELSE salary * 1.10
        END

    WHEN performance_rating = 'C' THEN salary
END AS new_salary
FROM Employee;

-- %%
--2.Department and Performance Scenario: You are tasked with giving bonuses based on the department, performance rating, and experience: · For Finance department: o If performance is 'A' and experience is more than 10 years, bonus is 25% of salary. o Otherwise, bonus is 20%. · For HR department: o If performance is 'B' or experience is greater than 5 years, the bonus is 15%. o Otherwise, the bonus is 10%. · For other departments, the bonus is 8%.


SELECT emp_name, salary,
CASE 
    WHEN department='finance' THEN
        CASE 
            WHEN performance_rating='A' and experience>10 THEN salary*0.25
            else salary*0.20
        end
    WHEN department='HR' THEN
        CASE 
            WHEN performance_rating='B' or experience>5 THEN salary*0.15
            else salary*0.10
        End
    ELSE salary*0.10
END AS bonus
from employee;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>bonus</th></tr></thead><tbody><tr><td>Karthik</td><td>95000</td><td>9500.00</td></tr><tr><td>Prathik</td><td>55000</td><td>8250.00</td></tr><tr><td>Vinay</td><td>78000</td><td>7800.00</td></tr><tr><td>Vijay</td><td>48000</td><td>4800.00</td></tr><tr><td>Anil</td><td>88000</td><td>8800.00</td></tr><tr><td>Suresh</td><td>92000</td><td>9200.00</td></tr><tr><td>Ramesh</td><td>46000</td><td>4600.00</td></tr><tr><td>Mahesh</td><td>67000</td><td>6700.00</td></tr><tr><td>Rajesh</td><td>72000</td><td>7200.00</td></tr><tr><td>Naveen</td><td>61000</td><td>6100.00</td></tr><tr><td>Deepak</td><td>83000</td><td>12450.00</td></tr><tr><td>Arjun</td><td>54000</td><td>5400.00</td></tr><tr><td>Kiran</td><td>76000</td><td>7600.00</td></tr><tr><td>Rohit</td><td>68000</td><td>6800.00</td></tr><tr><td>Pavan</td><td>59000</td><td>8850.00</td></tr><tr><td>Srikanth</td><td>102000</td><td>10200.00</td></tr><tr><td>Manoj</td><td>47000</td><td>4700.00</td></tr><tr><td>Varun</td><td>52000</td><td>5200.00</td></tr><tr><td>Ashok</td><td>74000</td><td>11100.00</td></tr><tr><td>Sunil</td><td>66000</td><td>6600.00</td></tr><tr><td>Nikhil</td><td>86000</td><td>8600.00</td></tr><tr><td>Harish</td><td>45000</td><td>4500.00</td></tr><tr><td>Vamsi</td><td>79000</td><td>7900.00</td></tr><tr><td>Chaitanya</td><td>91000</td><td>13650.00</td></tr><tr><td>Lokesh</td><td>58000</td><td>5800.00</td></tr></tbody></table></div>

-- %%
--Problem 3: Nested CASE for Employee Categorization Based on Salary, Performance, and ExperienceScenario: Categorize employees based on their salary, performance rating, and experience: · If salary is above 70,000: o If performance is 'A', and experience is more than 8 years, they are labeled 'Top Performer'. o If experience is less than 8 years, label them as 'Mid Performer'. · If salary is between 50,000 and 70,000, they are 'Average Performer' unless their performance is 'A', in which case they are 'Rising Star'. · If salary is below 50,000, they are 'Low Performer'.


SELECT emp_name, salary, performance_rating, experience,
CASE 
    WHEN salary > 70000 THEN 
        CASE 
            WHEN performance_rating = 'A' AND experience > 8 THEN 'Top Performer'
            ELSE 'Mid Performer'
        END
    WHEN salary BETWEEN 50000 AND 70000 THEN 
        CASE 
            WHEN performance_rating = 'A' THEN 'Rising Star'
            ELSE 'Average Performer'
        END
    WHEN salary < 50000 THEN 'Low Performer'
END AS category
FROM Employee;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>performance_rating</th><th>experience</th><th>category</th></tr></thead><tbody><tr><td>Karthik</td><td>95000</td><td>A</td><td>9</td><td>Top Performer</td></tr><tr><td>Prathik</td><td>55000</td><td>B</td><td>4</td><td>Average Performer</td></tr><tr><td>Vinay</td><td>78000</td><td>B</td><td>10</td><td>Mid Performer</td></tr><tr><td>Vijay</td><td>48000</td><td>C</td><td>3</td><td>Low Performer</td></tr><tr><td>Anil</td><td>88000</td><td>A</td><td>6</td><td>Mid Performer</td></tr><tr><td>Suresh</td><td>92000</td><td>A</td><td>12</td><td>Top Performer</td></tr><tr><td>Ramesh</td><td>46000</td><td>C</td><td>2</td><td>Low Performer</td></tr><tr><td>Mahesh</td><td>67000</td><td>B</td><td>7</td><td>Average Performer</td></tr><tr><td>Rajesh</td><td>72000</td><td>B</td><td>5</td><td>Mid Performer</td></tr><tr><td>Naveen</td><td>61000</td><td>C</td><td>6</td><td>Average Performer</td></tr><tr><td>Deepak</td><td>83000</td><td>A</td><td>11</td><td>Top Performer</td></tr><tr><td>Arjun</td><td>54000</td><td>C</td><td>3</td><td>Average Performer</td></tr><tr><td>Kiran</td><td>76000</td><td>A</td><td>8</td><td>Mid Performer</td></tr><tr><td>Rohit</td><td>68000</td><td>B</td><td>4</td><td>Average Performer</td></tr><tr><td>Pavan</td><td>59000</td><td>B</td><td>5</td><td>Average Performer</td></tr><tr><td>Srikanth</td><td>102000</td><td>A</td><td>14</td><td>Top Performer</td></tr><tr><td>Manoj</td><td>47000</td><td>C</td><td>2</td><td>Low Performer</td></tr><tr><td>Varun</td><td>52000</td><td>B</td><td>6</td><td>Average Performer</td></tr><tr><td>Ashok</td><td>74000</td><td>A</td><td>9</td><td>Top Performer</td></tr><tr><td>Sunil</td><td>66000</td><td>B</td><td>4</td><td>Average Performer</td></tr><tr><td>Nikhil</td><td>86000</td><td>A</td><td>7</td><td>Mid Performer</td></tr><tr><td>Harish</td><td>45000</td><td>C</td><td>1</td><td>Low Performer</td></tr><tr><td>Vamsi</td><td>79000</td><td>B</td><td>8</td><td>Mid Performer</td></tr><tr><td>Chaitanya</td><td>91000</td><td>A</td><td>13</td><td>Top Performer</td></tr><tr><td>Lokesh</td><td>58000</td><td>B</td><td>5</td><td>Average Performer</td></tr></tbody></table></div>

-- %%
--4.Nested CASE for Tax Bracket Based on Salary and Experience Scenario: You want to determine the tax bracket of employees based on their salary and experience: · If salary is above 90,000: o If experience is more than 10 years, they fall into the 35% tax bracket. o Otherwise, they fall into the 30% tax bracket. · If salary is between 60,000 and 90,000: o If experience is more than 5 years, they fall into the 25% tax bracket. o Otherwise, they fall into the 20% tax bracket. · For salaries below 60,000, the tax rate is 15%.


SELECT emp_name, salary, experience,
CASE 
    WHEN salary > 90000 THEN 
        CASE 
            WHEN experience > 10 THEN '35%'
            ELSE '30%'
        END

    WHEN salary BETWEEN 60000 AND 90000 THEN 
        CASE 
            WHEN experience > 5 THEN '25%'
            ELSE '20%'
        END

    ELSE '15%'
END AS tax_rate
FROM Employee;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>experience</th><th>tax_rate</th></tr></thead><tbody><tr><td>Karthik</td><td>95000</td><td>9</td><td>30%</td></tr><tr><td>Prathik</td><td>55000</td><td>4</td><td>15%</td></tr><tr><td>Vinay</td><td>78000</td><td>10</td><td>25%</td></tr><tr><td>Vijay</td><td>48000</td><td>3</td><td>15%</td></tr><tr><td>Anil</td><td>88000</td><td>6</td><td>25%</td></tr><tr><td>Suresh</td><td>92000</td><td>12</td><td>35%</td></tr><tr><td>Ramesh</td><td>46000</td><td>2</td><td>15%</td></tr><tr><td>Mahesh</td><td>67000</td><td>7</td><td>25%</td></tr><tr><td>Rajesh</td><td>72000</td><td>5</td><td>20%</td></tr><tr><td>Naveen</td><td>61000</td><td>6</td><td>25%</td></tr><tr><td>Deepak</td><td>83000</td><td>11</td><td>25%</td></tr><tr><td>Arjun</td><td>54000</td><td>3</td><td>15%</td></tr><tr><td>Kiran</td><td>76000</td><td>8</td><td>25%</td></tr><tr><td>Rohit</td><td>68000</td><td>4</td><td>20%</td></tr><tr><td>Pavan</td><td>59000</td><td>5</td><td>15%</td></tr><tr><td>Srikanth</td><td>102000</td><td>14</td><td>35%</td></tr><tr><td>Manoj</td><td>47000</td><td>2</td><td>15%</td></tr><tr><td>Varun</td><td>52000</td><td>6</td><td>15%</td></tr><tr><td>Ashok</td><td>74000</td><td>9</td><td>25%</td></tr><tr><td>Sunil</td><td>66000</td><td>4</td><td>20%</td></tr><tr><td>Nikhil</td><td>86000</td><td>7</td><td>25%</td></tr><tr><td>Harish</td><td>45000</td><td>1</td><td>15%</td></tr><tr><td>Vamsi</td><td>79000</td><td>8</td><td>25%</td></tr><tr><td>Chaitanya</td><td>91000</td><td>13</td><td>35%</td></tr><tr><td>Lokesh</td><td>58000</td><td>5</td><td>15%</td></tr></tbody></table></div>

-- %%
--Problem 5: Nested CASE for Promotion Eligibility Based on Performance, Salary, and Experience Scenario: You want to determine if employees are eligible for promotion based on their performance rating, salary, and experience: · If performance is 'A': § If salary is more than 75,000 and experience is greater than 7 years, they are 'Eligible for Senior Role'. § Otherwise, they are 'Eligible for Junior Role'. · If performance is 'B': § If experience is more than 5 years, they are 'Eligible for Consideration'. § Otherwise, they are 'Not Eligible'. · If performance is 'C', they are automatically 'Not Eligible'


SELECT emp_name, salary, experience, performance_rating,
CASE 
    WHEN performance_rating = 'A' THEN 
        CASE 
            WHEN salary > 75000 AND experience > 7 THEN 'Eligible for Senior Role'
            ELSE 'Eligible for Junior Role'
        END

    WHEN performance_rating = 'B' THEN 
        CASE 
            WHEN experience > 5 THEN 'Eligible for Consideration'
            ELSE 'Not Eligible'
        END

    WHEN performance_rating = 'C' THEN 'Not Eligible'
END AS promotion_status
FROM Employee;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>salary</th><th>experience</th><th>performance_rating</th><th>promotion_status</th></tr></thead><tbody><tr><td>Karthik</td><td>95000</td><td>9</td><td>A</td><td>Eligible for Senior Role</td></tr><tr><td>Prathik</td><td>55000</td><td>4</td><td>B</td><td>Not Eligible</td></tr><tr><td>Vinay</td><td>78000</td><td>10</td><td>B</td><td>Eligible for Consideration</td></tr><tr><td>Vijay</td><td>48000</td><td>3</td><td>C</td><td>Not Eligible</td></tr><tr><td>Anil</td><td>88000</td><td>6</td><td>A</td><td>Eligible for Junior Role</td></tr><tr><td>Suresh</td><td>92000</td><td>12</td><td>A</td><td>Eligible for Senior Role</td></tr><tr><td>Ramesh</td><td>46000</td><td>2</td><td>C</td><td>Not Eligible</td></tr><tr><td>Mahesh</td><td>67000</td><td>7</td><td>B</td><td>Eligible for Consideration</td></tr><tr><td>Rajesh</td><td>72000</td><td>5</td><td>B</td><td>Not Eligible</td></tr><tr><td>Naveen</td><td>61000</td><td>6</td><td>C</td><td>Not Eligible</td></tr><tr><td>Deepak</td><td>83000</td><td>11</td><td>A</td><td>Eligible for Senior Role</td></tr><tr><td>Arjun</td><td>54000</td><td>3</td><td>C</td><td>Not Eligible</td></tr><tr><td>Kiran</td><td>76000</td><td>8</td><td>A</td><td>Eligible for Senior Role</td></tr><tr><td>Rohit</td><td>68000</td><td>4</td><td>B</td><td>Not Eligible</td></tr><tr><td>Pavan</td><td>59000</td><td>5</td><td>B</td><td>Not Eligible</td></tr><tr><td>Srikanth</td><td>102000</td><td>14</td><td>A</td><td>Eligible for Senior Role</td></tr><tr><td>Manoj</td><td>47000</td><td>2</td><td>C</td><td>Not Eligible</td></tr><tr><td>Varun</td><td>52000</td><td>6</td><td>B</td><td>Eligible for Consideration</td></tr><tr><td>Ashok</td><td>74000</td><td>9</td><td>A</td><td>Eligible for Junior Role</td></tr><tr><td>Sunil</td><td>66000</td><td>4</td><td>B</td><td>Not Eligible</td></tr><tr><td>Nikhil</td><td>86000</td><td>7</td><td>A</td><td>Eligible for Junior Role</td></tr><tr><td>Harish</td><td>45000</td><td>1</td><td>C</td><td>Not Eligible</td></tr><tr><td>Vamsi</td><td>79000</td><td>8</td><td>B</td><td>Eligible for Consideration</td></tr><tr><td>Chaitanya</td><td>91000</td><td>13</td><td>A</td><td>Eligible for Senior Role</td></tr><tr><td>Lokesh</td><td>58000</td><td>5</td><td>B</td><td>Not Eligible</td></tr></tbody></table></div>
